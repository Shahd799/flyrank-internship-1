# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Shahd799/flyrank-internship-1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# I chose **Lane 2: Refresh / Content Opportunity Scoring**.
#
# This project is mainly a **ranking and scoring** task. The goal is not simply to classify pages as good or bad, but to rank them according to their priority for content review. Each page receives a priority score so content teams can decide which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# The target is to identify pages that should be prioritized for review.
#
# Since there is no direct label that says a page "needs refresh", I use **trend_direction** as a proxy. Pages with a **down** trend are treated as pages that may need review. This is an observed signal rather than a guaranteed outcome.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# I would use **Precision@20** (or Precision@50) as the main success metric.
#
# The goal is to ensure that the highest-ranked pages are truly good candidates for review. A higher Precision@20 means that more of the top recommended pages actually deserve attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# The unit of analysis is **one content page**.
#
# Each row in the dataset represents one page and includes information such as impressions, CTR, average position, content age, and trend direction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import subprocess
import pandas as pd

REPO_URL = "https://github.com/Shahd799/flyrank-internship-1"
REPO_DIR = "flyrank-internship-1"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir(REPO_DIR)

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset shape:", df.shape)

df[[
    "content_age_days",
    "impressions_90d",
    "ctr",
    "avg_position",
    "trend_direction"
]].head()
# Out:
# Dataset shape: (30000, 44)
#    content_age_days  impressions_90d   ctr  avg_position trend_direction
# 0               187             3803  0.76          10.6            down
# 1               445            15320  0.05          20.3            down
# 2               141            12581  0.09          36.5            down
# 3               463            11751  0.49           6.2          stable
# 4               263            19140  0.13          44.0            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
#
# A simple rule can only use one or two conditions, such as "review pages older than 180 days".
#
# Machine learning can combine several signals, including **impressions, CTR, average position, content age, and trend direction,** to produce a more useful ranking.
#
# This allows content teams to prioritize pages more effectively than relying on one fixed rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
