# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahd799/flyrank-internship-1/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Shahd799/flyrank-internship-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#  **Lane 2: Refresh / Content Opportunity Scoring.**
#
# I chose this lane because content teams often have thousands of pages and cannot review all of them manually. A ranking system can help prioritize which pages should be reviewed first based on observable performance signals such as impressions, CTR, content age, and trend direction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ### Question
#
# Which pages should be reviewed first for content refresh?
#
# ### Decision
#
# This project helps decide which pages should be prioritized for review.
#
# ### Action
#
# A content editor can update, improve, or monitor the pages with the highest priority.
#
# ### Cost of a wrong recommendation
#
# A wrong recommendation may waste time reviewing pages that do not need updates, while truly important pages may be ignored.
#
# ### Why Machine Learning?
#
# Machine learning can combine several signals together and rank pages more effectively than using one simple manual rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# **Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.**
#
# The starter dataset contains **30,000 pages**.
#
# Among them, **16,262 pages** have a downward trend, while the remaining pages are stable, improving, new, or flat.
#
# The average CTR is **0.511**.
#
# These observations suggest that there are many pages with different performance patterns, making this dataset suitable for building a page-priority ranking system.

# %%
import os
import subprocess

REPO_URL = "https://github.com/Shahd799/flyrank-internship-1"
REPO_DIR = "flyrank-internship-1"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir(REPO_DIR)

print(os.getcwd())
# Out:
# /content/flyrank-internship-1/flyrank-internship-1/flyrank-internship-1

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print(df["trend_direction"].value_counts())
print("Average CTR:", round(df["ctr"].mean(), 3))
# Out:
# Number of pages: 30000
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# Average CTR: 0.511

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ##
#
# This project provides decision support based on observed search signals.
#
# The model can help identify pages that may deserve review, but it cannot guarantee that updating a page will improve its ranking or traffic.
#
# The analysis is observational and should not be interpreted as proving how Google's ranking algorithm works.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
